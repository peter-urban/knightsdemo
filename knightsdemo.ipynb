# %%
import knightswhosaydb as kdb

# %%
kdb.mosaic(
    dir_path = r'Y:\Egmont_Key\kmall',  #do not end on \
    format = 'kmall',
    out_lines = 'lines',
    mosaic_path = 'egmont.tif',         #output mosaic
    crs = "EPSG:32617",                 #crs your survey area, please use UTM one
    save_lines=True,
    res=1.0                            # resolution in meters
)
# Out:
# Found 14 files
# Processing file 1 of 14: 0000_20240726_132023.kmall
# Processing file 2 of 14: 0001_20240726_133732.kmall
# Processing file 3 of 14: 0003_20240726_135910.kmall
# Processing file 4 of 14: 0004_20240726_141430.kmall
# Processing file 5 of 14: 0005_20240726_142357.kmall
# Processing file 6 of 14: 0006_20240726_143243.kmall
# Processing file 7 of 14: 0007_20240726_144003.kmall
# Processing file 8 of 14: 0007_20240726_150251.kmall
# Processing file 9 of 14: 0008_20240726_151119.kmall
# Processing file 10 of 14: 0009_20240726_152723.kmall
# Processing file 11 of 14: 0012_20240726_153714.kmall
# Processing file 12 of 14: 0013_20240726_154054.kmall
# Processing file 13 of 14: 0014_20240726_155614.kmall
# Processing file 14 of 14: 9999.kmall
# Found 14 raster files to mosaic
# Processing complete. Output mosaic saved as: egmont.tif
# Lines saved to: lines
