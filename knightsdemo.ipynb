# %%
import knightswhosaydb as kdb

# %%
kdb.mosaic(
    dir_path = r'/home/data/test_data/Egmont_Key/kmall/',  #do not end on \
    format = 'kmall',
    out_lines = 'lines',
    mosaic_path = 'egmont.tif',         #output mosaic
    crs = "EPSG:32617",                 #crs your survey area, please use UTM one
    save_lines=True,
    res=0.33                            # resolution in meters
)
