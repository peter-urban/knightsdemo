# %%
import knightswhosaydb as kdb

# %%
# !rm -r lines

# %%
kdb.mosaic(
    dir_path = r'/home/data/test_data/knightstestdata/alex/EM2040/EM 2040 Dual TX/20210430_REVI_MultiFrequency/',  #do not end on \
    format = 'kmall',
    out_lines = 'lines',
    mosaic_path = 'egmont.tif',         #output mosaic
    crs = "EPSG:32632",                 #crs your survey area, please use UTM one
    save_lines=True,
    res=0.33                            # resolution in meters
)
# Out:
# Found 3 files
# Processing files:   0%|          | 0/3 [00:00<?, ?file/s]
# WARNING in file [0]: /home/data/test_data/knightstestdata/alex/EM2040/EM 2040 Dual TX/20210430_REVI_MultiFrequency/0010_20210430_123637.kmall
# KMALLNavigationDataInterfacePerFile::read_navigation_data: S_POSITION datagrams are not in chronological order and will be sorted. This could indicate a navigation data problem.

# %%
import themachinethatgoesping
themachinethatgoesping.__version__
# Out:
# '0.35.1'
